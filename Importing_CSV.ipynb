# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/nagarjuna18/Importing-CSV.ipynb/blob/master/Importing_CSV.ipynb)

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file_list = drive.ListFile({'q': "'1Vwo9D3wrtNg1yGVFJVhjT_pkfE8SwzpH' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: honeyproduction.csv, id: 1KGCZLiHuCQ8qL3wqaO6FtF8ijXWHeaRW
# title: Untitled0.ipynb, id: 1NgzY0thHlbFKSAcgjGqvB9z_hJ3MIJMZ
# title: Upload/Histrogram.ipynb, id: 1CYhh4hoUErFmIVPmBx0QQBZQjm5MyP3g
# title: webscrap2.ipynb, id: 1ToVZY1JBXqPGTIsv8Wfl98zTckeSROBe
# title: data.txt, id: 1wQX3genBFlsxbONhGwOcltmiThcjK4Lw
# title: web scrap1.ipynb, id: 1QZO9exQfhKtZ0f_MspOpnCBzDAkGS_93

# %%
train_downloaded = drive.CreateFile({'id': '1KGCZLiHuCQ8qL3wqaO6FtF8ijXWHeaRW'})
train_downloaded.GetContentFile('train.csv')
test_downloaded = drive.CreateFile({'id': '1KGCZLiHuCQ8qL3wqaO6FtF8ijXWHeaRW'})
test_downloaded.GetContentFile('test.csv')

# %%
import pandas as pd
import numpy as np
df_train = pd.read_csv('train.csv')
df_train
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# 5      FL  230000.0           98  22540000.0   4508000.0        0.64
# 6      GA   75000.0           56   4200000.0    307000.0        0.69
# 7      HI    8000.0          118    944000.0     66000.0        0.77
# 8      ID  120000.0           50   6000000.0   2220000.0        0.65
# 9      IL    9000.0           71    639000.0    204000.0        1.19
# 10     IN    9000.0           92    828000.0    489000.0        0.85
# 11     IA   50000.0           78   3900000.0   2301000.0        0.70
# 12     KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
df_test = pd.read_csv('test.csv')
stocks = df_test['yieldpercol']
print(stocks)
print("max=",max(stocks),'\n',"min=",min(stocks))
# Out:
# 0       71
# 1       60
# 2       65
# 3       83
# 4       72
# 5       98
# 6       56
# 7      118
# 8       50
# 9       71
# 10      92
# 11      78
# 12      46
# 13      50
# 14     111
# 15      26
# 16      44
# 17      85
# 18      79
# 19      86
# 20      66
# 21     122
# 22      70
# 23      46
# 24      49
# 25      55
# 26      80
# 27      59
# 28     128
# 29      78
#       ...
# 596     59
# 597     61
# 598     55
# 599     51
# 600     86
# 601     34
# 602     57
# 603     67
# 604    118
# 605     53
# 606     52
# 607     65
# 608     33
# 609     52
# 610     51
# 611     39
# 612     69
# 613     60
# 614     32
# 615     60
# 616     63
# 617     61
# 618     52
# 619     38
# 620     60
# 621     41
# 622     41
# 623     48
# 624     69
# 625     51
# Name: yieldpercol, Length: 626, dtype: int64
# max= 136
#  min= 19

# %%
import matplotlib.pyplot as plt
#plt.hist(stocks,bins=50)
plt.plot(list(stocks))
plt.hist(stocks,bins=int(136/19))
plt.axis([0, 140, 1900, 2000])
plt.ylabel('Years')
plt.xlabel('stock points')
plt.show()
